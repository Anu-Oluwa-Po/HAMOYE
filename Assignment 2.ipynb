# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
energy = pd.read_csv('energydata_complete.csv')
energy.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
energy.shape
# Out:
# (19735, 29)

# %%
energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %%
energy.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %%
from sklearn.linear_model import LinearRegression

x = energy[['T2']]
y = energy['T6']


from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

lr = LinearRegression()
lr.fit(x_train, y_train)
pred = lr.predict(x_test)
rmse = np.sqrt(mean_squared_error(y_test, pred))
round(rmse, 3)
# Out:
# 3.63

# %%
energy = energy.drop(['date', 'lights'], axis=1)
features = energy.drop(['Appliances'], axis=1)
target = energy['Appliances']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
x_train = pd.DataFrame(scaler.fit_transform(x_train), columns=features.columns)
x_test = pd.DataFrame(scaler.fit_transform(x_test), columns=features.columns)

# %%
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

lr = LinearRegression()
lr.fit(x_train, y_train)
pred = lr.predict(x_train)

# %%
mae = mean_absolute_error(y_train, pred)
round(mae, 3)
# Out:
# 53.742

# %%
rmse = np.sqrt(mean_squared_error(y_train, pred))
round(rmse, 3)
# Out:
# 95.216

# %%
pred = lr.predict(x_test)
mae= mean_absolute_error(y_test, pred)
round(mae, 3)
# Out:
# 49.093

# %%
pred = lr.predict(x_test)
rmse = np.sqrt(mean_squared_error(y_test, pred))
round(rmse, 3)
# Out:
# 97.531

# %%
ridge = Ridge()
ridge.fit(x_train, y_train)
# Out:
# Ridge()

# %%
pred = ridge.predict(x_test)
np.sqrt(mean_squared_error(y_test, pred))
# Out:
# 98.64997676309154

# %%
lasso = Lasso()
lasso.fit(x_train, y_train)
# Out:
# Lasso()

# %%
preds = lasso.predict(x_test)
np.sqrt(mean_squared_error(y_test, preds))
# Out:
# 101.5018894144909

# %%
def weights(model, features, column_name):
    weight = pd.Series(model.coef_, features.columns).sort_values()
    weight_df = pd.DataFrame(weight).reset_index()
    weight_df.columns = ["Features", column_name]
    weight_df[column_name].round(3)
    return weight_df

# %%
lr_weights = weights(lr, features, 'LinearRegression')
ridge_w = weights(ridge, features, 'RidgeRegression')
lasso_w = weights(lasso, features, 'LassoRegression')

weight_data = pd.merge(lr_weights, ridge_w, on='Features')
weight_data = pd.merge(weight_data, lasso_w, on='Features')

# %%
weight_data
# Out:
#        Features  LinearRegression  RidgeRegression  LassoRegression
# 0          RH_2     -16697.744717       -71.127952             -0.0
# 1         T_out     -10676.085192       216.668799              0.0
# 2        RH_out      -6233.069918      -252.560260             -0.0
# 3          RH_8      -4807.560361      -611.386989             -0.0
# 4            T2      -3459.605006       653.378842              0.0
# 5            T9      -1930.747958      -461.016519              0.0
# 6          RH_7      -1341.292153      -395.279191             -0.0
# 7          RH_9      -1013.554863      -387.812241             -0.0
# 8            T5       -174.061818      -275.807924              0.0
# 9            T1        -33.246564       -14.667055              0.0
# 10          rv2         41.166131        -0.346975             -0.0
# 11          rv1         41.166131        -0.346975             -0.0
# 12           T7        116.741133       -87.385981              0.0
# ...

# %%
#My answers are different from that of the quiz because i was tensed by the time so i couldn't process the questions well
